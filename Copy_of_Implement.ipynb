# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeChivalry/SpaceHack/blob/main/Copy_of_Implement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CHANDRAYAAN-3

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('propulsion_module.csv')

# %%
df
# Out:
#     Sr. No.                  Parameter   \
# 0        NaN                        NaN
# 1        0.0          Lunar Polar Orbit
# 2        1.0               Mission life
# 3        2.0                  Structure
# 4        3.0                   Dry Mass
# 5        4.0            Propellant Mass
# 6        5.0              Total PM Mass
# 7        6.0           Power Generation
# 8        7.0              Communication
# 9        8.0           Attitude Sensors
# 10       9.0          Propulsion System
# 11      10.0                  undefined
# 12      11.0  # Lander Module dataframe
# 13      12.0                  undefined
# 14      13.0                  Parameter
# 15      14.0                          -
# 16      15.0               Mission life
# 17      16.0                       Mass
# 18      17.0                      Power
# 19      18.0                   Payloads
# 20      19.0           Dimensions (mm3)
# 21      20.0              Communication
# 22      21.0               Landing site
# 23      22.0                  undefined
# 24      23.0          # Rover dataframe
# 25      24.0                  undefined
# 26      25.0                  Parameter
# 27      26.0                          -
# 28      27.0               Mission Life
# 29      28.0                       Mass
# 30      29.0                      Power
# 31      30.0                   Payloads
# 32      31.0           Dimensions (mm3)
# 33      32.0              Communication
#
#                                    Chandrayaan-1  \
# 0                                            NaN
# 1                                    500X7500 km
# 2                                        2 years
# 3                      Modified version of I-3 K
# 4                                         560 kg
# 5                                         1380kg
# 6                                         1380kg
# 7                                      750 watts
# 8           S-Band Transponder (TTC) – with IDSN
# 9                            two-axis Sun sensor
# 10  Bi-Propellant Propulsion System (MMH + MON3)
# 11                                     undefined
# 12                                     undefined
# 13                                     undefined
# 14                                Specifications
# 15                                             -
# 16                                      312 days
# 17                    1380 kg (Mass at lift off)
# 18                                     700 Watts
# 19                                            -
# 20                                   150x150x150
# 21                                          IDSN
# 22                                            -
# 23                                     undefined
# 24                                     undefined
# 25                                     undefined
# 26                                Specifications
# 27                                             -
# 28                                      312 days
# 29                                            -
# 30                                            -
# 31                                             -
# 32                                   150x150x150
# 33                                       antenna
#
#                        Chandrayaan-2  \
# 0                                NaN
# 1                         100x100 km
# 2        3 years, 11 months, 23 days
# 3          Modified version of I-3 K
# 4                             626 kg
# 5                           1,697 kg
# 6                           2,379 kg
# 7                         1000 Watts
# 8   Indian Deep Space Network (IDSN)
# 9                        star sensor
# 10                               NaN
# 11                         undefined
# 12                         undefined
# 13                         undefined
# 14                    Specifications
# 15                                 -
# 16       1 Lunar day (14 Earth days)
# 17                          1,471 kg
# 18                             650 W
# 19                                 3
# 20                 2540× 2000 × 1200
# 21                              IDSN
# 22                    70.9 S, 22.7 E
# 23                         undefined
# 24                         undefined
# 25                         undefined
# 26                    Specifications
# 27                                 -
# 28                       1 Lunar day
# 29                             27 kg
# 30                              50 W
# 31                                 2
# 32                   900 × 750 × 850
# 33                            lander
#
#                                         Chandrayaan-3
# 0                                                 NaN
# 1            From 170 x 36500 km to lunar polar orbit
# 2   Carrying Lander Module & Rover upto ~100 x 100...
# 3                           Modified version of I-3 K
# 4                    448.62 kg (including pressurant)
# 5                                          1696.39 kg
# 6                                          2145.01 kg
# 7              738 W, Summer solistices and with bias
# 8                S-Band Transponder (TTC) – with IDSN
# 9                       CASS, IRAP, Micro star sensor
# 10       Bi-Propellant Propulsion System (MMH + MON3)
# 11                                          undefined
# 12                                          undefined
# 13                                          undefined
# 14                                     Specifications
# 15                                                  -
# 16                        1 Lunar day (14 Earth days)
# 17                         1749.86 kg including Rover
# 18                            738 W (Winter solstice)
# 19                                                  3
# 20                                 2000 x 2000 x 1166
# 21                          ISDN, Ch-2 Orbiter, Rover
# 22                           69.367621 S, 32.348126 E
# 23                                          undefined
# 24                                          undefined
# 25                                          undefined
# 26                                     Specifications
# 27                                                  -
# 28                                        1 Lunar day
# 29                                              26 kg
# 30                                               50 W
# 31                                                  2
# 32                                    917 x 750 x 397
# 33                                             Lander

# %%
data = {
 "Parameter": [
 "Lunar Polar Orbit",
 "Mission life",
 "Structure",
 "Dry Mass",
 "Propellant Mass",
 "Total PM Mass",
 "Power Generation",
 "Communication",
 "Attitude Sensors",
 "Propulsion System"
 ],
 "Specifications": [
 "From 170 x 36500 km to lunar polar orbit",
 "Carrying Lander Module & Rover upto ~100 x 100 km launch injection.",
 "Modified version of I-3 K",
 "448.62 kg (including pressurant)",
 "1696.39 kg",
 "2145.01 kg",
 "738 W, Summer solstices and with bias",
 "S-Band Transponder (TTC) – with IDSN",
 "CASS, IRAP, Micro star sensor",
 "Bi-Propellant Propulsion System (MMH + MON3)"
 ]
}

# %%
import pandas as pd



# Extract the datasets for propulsion, lander, and rover
propulsion_data1 = df['Chandrayaan-1'][df['Sr. No. '].between(0, 9)]
lander_data2 = df['Chandrayaan-1'][df['Sr. No. '].between(15, 21)]
rover_data3 = df['Chandrayaan-1'][df['Sr. No. '].between(27, 32)]

# Assign these datasets to data1, data2, and data3, ...
data1 = propulsion_data1
data2 = lander_data2
data3 = rover_data3

propulsion_data4 = df['Chandrayaan-2'][df['Sr. No. '].between(0, 9)]
lander_data5 = df['Chandrayaan-2'][df['Sr. No. '].between(15, 21)]
rover_data6 = df['Chandrayaan-2'][df['Sr. No. '].between(27, 32)]


data4 = propulsion_data4
data5 = lander_data5
data6 = rover_data6

propulsion_data7 = df['Chandrayaan-3'][df['Sr. No. '].between(0, 9)]
lander_data8 = df['Chandrayaan-3'][df['Sr. No. '].between(15, 21)]
rover_data9 = df['Chandrayaan-3'][df['Sr. No. '].between(27, 32)]

data7 = propulsion_data7
data8 = lander_data8
data9 = rover_data9

# %%
propulsion_df = pd.DataFrame(data)

# %%
propulsion_df
# Out:
#            Parameter                                     Specifications
# 0  Lunar Polar Orbit           From 170 x 36500 km to lunar polar orbit
# 1       Mission life  Carrying Lander Module & Rover upto ~100 x 100...
# 2          Structure                          Modified version of I-3 K
# 3           Dry Mass                   448.62 kg (including pressurant)
# 4    Propellant Mass                                         1696.39 kg
# 5      Total PM Mass                                         2145.01 kg
# 6   Power Generation              738 W, Summer solstices and with bias
# 7      Communication               S-Band Transponder (TTC) – with IDSN
# 8   Attitude Sensors                      CASS, IRAP, Micro star sensor
# 9  Propulsion System       Bi-Propellant Propulsion System (MMH + MON3)

# %%
propulsion_data1
# Out:
# 1                                      500X7500 km
# 2                                          2 years
# 3                        Modified version of I-3 K
# 4                                           560 kg
# 5                                           1380kg
# 6                                           1380kg
# 7                                        750 watts
# 8             S-Band Transponder (TTC) – with IDSN
# 9                              two-axis Sun sensor
# 10    Bi-Propellant Propulsion System (MMH + MON3)
# Name: Chandrayaan-1, dtype: object

# %%
data = {
 "Parameter": [
 "Mission life",
 "Mass",
 "Power",
 "Payloads",
 "Dimensions (mm3)",
 "Communication",
 "Landing site"
 ],
 "Specifications": [
 "1 Lunar day (14 Earth days)",
 "1749.86 kg including Rover",
 "738 W (Winter solstice)",
 "3",
 "2000 x 2000 x 1166",
 "ISDN, Ch-2 Orbiter, Rover",
 "69.367621 S, 32.348126 E"
 ]
}

# %%
lander_df = pd.DataFrame(data)

# %%
lander_data2
# Out:
# 16                      312 days
# 17    1380 kg (Mass at lift off)
# 18                     700 Watts
# 19                            -
# 20                   150x150x150
# 21                          IDSN
# 22                            -
# Name: Chandrayaan-1, dtype: object

# %%
rover_data3
# Out:
# 28       312 days
# 29             -
# 30             -
# 31              -
# 32    150x150x150
# 33        antenna
# Name: Chandrayaan-1, dtype: object

# %%
def extract_numerical_value(spec):
 numeric_pattern = r'(\d+(\.\d+)?)'
 custom_numeric_pattern = r"[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?"

 combined_pattern = f"({numeric_pattern}|{custom_numeric_pattern})"

 matches = re.findall(combined_pattern, spec)

 if matches:
  return float(matches[0][0])
 else:
  return None

# %%
import re

# %%
propulsion_data1["Numerical Value"] = propulsion_df["Specifications"].apply(extract_numerical_value)

# %%
propulsion_data1
# Out:
# 1                                                        500X7500 km
# 2                                                            2 years
# 3                                          Modified version of I-3 K
# 4                                                             560 kg
# 5                                                             1380kg
# 6                                                             1380kg
# 7                                                          750 watts
# 8                               S-Band Transponder (TTC) – with IDSN
# 9                                                two-axis Sun sensor
# 10                      Bi-Propellant Propulsion System (MMH + MON3)
# Numerical Value    0     170.00
# 1     100.00
# 2      -3.00
# 3     4...
# Name: Chandrayaan-1, dtype: object

# %%
lander_data2["Numerical Value"] = lander_df["Specifications"].apply(extract_numerical_value)

# %%
lander_data2
# Out:
# 16                                                          312 days
# 17                                        1380 kg (Mass at lift off)
# 18                                                         700 Watts
# 19                                                                -
# 20                                                       150x150x150
# 21                                                              IDSN
# 22                                                                -
# Numerical Value    0       1.000000
# 1    1749.860000
# 2     738.00...
# Name: Chandrayaan-1, dtype: object

# %%
data = {
 "Parameter": [
 "Mission Life",
 "Mass",
 "Power",
 "Payloads",
 "Dimensions (mm3)",
 "Communication"
 ],
 "Specifications": [
 "1 Lunar day",
 "26 kg",
 "50 W",
 "2",
 "917 x 750 x 397",
 "Lander"
 ]
}

# %%
rover_df = pd.DataFrame(data)

# %%
rover_data3["Numerical Value"] = rover_df["Specifications"].apply(extract_numerical_value)

# %%
rover_data3
# Out:
# 28                                                          312 days
# 29                                                                -
# 30                                                                -
# 31                                                                 -
# 32                                                       150x150x150
# 33                                                           antenna
# Numerical Value    0      1.0
# 1     26.0
# 2     50.0
# 3      2.0
# 4 ...
# Name: Chandrayaan-1, dtype: object

# %%
import math

# %%
rover_mass = 26
lander_dry_mass = 1749.86
total_mass = rover_mass + lander_dry_mass
delta_v_required = 1500
isp_lander_engine = 300
propellant_mass_required = total_mass * math.exp(delta_v_required / isp_lander_engine)
propellant_mass_required = round(propellant_mass_required, 2)

# %%
rover_power_requirement = 50
lander_battery_capacity = 2000
rover_operating_time_hours = lander_battery_capacity / rover_power_requirement

# %%
print("Mass Budget:")
print(f"Lander mass: {lander_dry_mass} kg")
print(f"Rover mass: {rover_mass} kg")
print(f"Propellant mass required: {propellant_mass_required} kg matches value in Lander")
print("\nPower Budget:")
print(f"Rover power requirement: {rover_power_requirement} W")
print(f"Lander battery capacity: {lander_battery_capacity} Wh")
print(f"Rover can operate for {rover_operating_time_hours:.2f} hours on stored power")
print("\nMobility Assessment:")
print("Low mass of the rover allows for mobility on uneven lunar surface")
print("Number of payloads for science measurements is 2")
# Out:
# Mass Budget:
# Lander mass: 1471 kg
# Rover mass: 27 kg
# Propellant mass required: 222322.91 kg matches value in Lander
#
# Power Budget:
# Rover power requirement: 50 W
# Lander battery capacity: 2000 Wh
# Rover can operate for 40.00 hours on stored power
#
# Mobility Assessment:
# Low mass of the rover allows for mobility on uneven lunar surface
# Number of payloads for science measurements is 2

# %%
import matplotlib.pyplot as plt
labels = ['Lander Dry Mass', 'Rover Mass', 'Propellant Mass']
mass_values = [lander_dry_mass, rover_mass, propellant_mass_required]
plt.figure(figsize=(8, 6))
plt.bar(labels, mass_values, color=['blue', 'green', 'orange'])
plt.xlabel('Components')
plt.ylabel('Mass (kg)')
plt.title('Mass Budget')
plt.ylim(0, max(mass_values) * 1.2)
for i, v in enumerate(mass_values):
 plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
labels = ['Rover Power Requirement', 'Lander Battery Capacity']
power_values = [rover_power_requirement, lander_battery_capacity]
plt.figure(figsize=(8, 6))
plt.bar(labels, power_values, color=['blue', 'green'])
plt.xlabel('Components')
plt.ylabel('Power (Watt-hours)')
plt.title('Power Budget')
plt.ylim(0, max(power_values) * 1.2)
for i, v in enumerate(power_values):
 plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
import plotly.express as px
mass_labels = ['Lander Dry Mass', 'Rover Mass', 'Propellant Mass']
mass_values = [lander_dry_mass, rover_mass, propellant_mass_required]
mass_fig = px.bar(x=mass_labels, y=mass_values, color=mass_labels,
 labels={'x': 'Components', 'y': 'Mass (kg)'},
 title='Mass Budget')
mass_fig.update_traces(texttemplate='%{y:.2f} kg', textposition='outside')
mass_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fd681b98-1668-4c95-b188-4ef43f533e2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd681b98-1668-4c95-b188-4ef43f533e2f")) {                    Plotly.newPlot(                        "fd681b98-1668-4c95-b188-4ef43f533e2f",                        [{"alignmentgroup":"True","hovertemplate":"color=Lander Dry Mass\u003cbr\u003eComponents=%{x}\u003cbr\u003eMass (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lander Dry Mass","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Lander Dry Mass","offsetgroup":"Lander Dry Mass","orientation":"v","showlegend":true,"textposition":"outside","x":["Lander Dry Mass"],"xaxis":"x","y":[1471.0],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} kg"},{"alignmentgroup":"True","hovertemplate":"color=Rover Mass\u003cbr\u003eComponents=%{x}\u003cbr\u003eMass (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rover Mass","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Rover Mass","offsetgroup":"Rover Mass","orientation":"v","showlegend":true,"textposition":"outside","x":["Rover Mass"],"xaxis":"x","y":[27.0],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} kg"},{"alignmentgroup":"True","hovertemplate":"color=Propellant Mass\u003cbr\u003eComponents=%{x}\u003cbr\u003eMass (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Propellant Mass","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Propellant Mass","offsetgroup":"Propellant Mass","orientation":"v","showlegend":true,"textposition":"outside","x":["Propellant Mass"],"xaxis":"x","y":[222322.91],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} kg"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26" ...

# %%
power_labels = ['Rover Power Requirement', 'Lander Battery Capacity']
power_values = [rover_power_requirement, lander_battery_capacity]
power_fig = px.bar(x=power_labels, y=power_values, color=power_labels,
 labels={'x': 'Components', 'y': 'Power (Watt-hours)'},
 title='Power Budget')
power_fig.update_traces(texttemplate='%{y:.2f} Wh', textposition='outside')
power_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="000faeb2-e739-4535-bc9d-06bff5fe3654" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("000faeb2-e739-4535-bc9d-06bff5fe3654")) {                    Plotly.newPlot(                        "000faeb2-e739-4535-bc9d-06bff5fe3654",                        [{"alignmentgroup":"True","hovertemplate":"color=Rover Power Requirement\u003cbr\u003eComponents=%{x}\u003cbr\u003ePower (Watt-hours)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rover Power Requirement","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rover Power Requirement","offsetgroup":"Rover Power Requirement","orientation":"v","showlegend":true,"textposition":"outside","x":["Rover Power Requirement"],"xaxis":"x","y":[50],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} Wh"},{"alignmentgroup":"True","hovertemplate":"color=Lander Battery Capacity\u003cbr\u003eComponents=%{x}\u003cbr\u003ePower (Watt-hours)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lander Battery Capacity","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Lander Battery Capacity","offsetgroup":"Lander Battery Capacity","orientation":"v","showlegend":true,"textposition":"outside","x":["Lander Battery Capacity"],"xaxis":"x","y":[2000],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} Wh"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %%
plt.figure(figsize=(20, 20))
plt.pie(mass_values, labels=mass_labels, autopct='%1.1f%%', startangle=140)
plt.title('Mass Budget')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(power_values, labels=power_labels, autopct='%1.1f%%', startangle=140)
plt.title('Power Budget')
plt.axis('equal')
plt.show()

# %%
mass_fig = px.pie(names=mass_labels, values=mass_values, title='Mass Budget')
mass_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fb969506-0633-4bde-ba85-75e0fbe5b849" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb969506-0633-4bde-ba85-75e0fbe5b849")) {                    Plotly.newPlot(                        "fb969506-0633-4bde-ba85-75e0fbe5b849",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Lander Dry Mass","Rover Mass","Propellant Mass"],"legendgroup":"","name":"","showlegend":true,"values":[1749.86,26.0,263560.99],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidt ...

# %%
power_fig = px.pie(names=power_labels, values=power_values, title='Power Budget')
power_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0d945b89-2461-49a7-b3c8-a84c1624b2a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d945b89-2461-49a7-b3c8-a84c1624b2a2")) {                    Plotly.newPlot(                        "0d945b89-2461-49a7-b3c8-a84c1624b2a2",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Rover Power Requirement","Lander Battery Capacity"],"legendgroup":"","name":"","showlegend":true,"values":[50,2000],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks" ...

# %%
surface_roughness = 8
permanently_shadowed_regions = True
extreme_cold_temperature = -157
extreme_hot_temperature = 120
limited_line_of_sight = True
signal_delays = True
low_sun_angle = True
abrasive_dust = 7
electrostatic_levitation = True
limited_landmarks = True
solar_radiation = 9
cosmic_radiation = 9
long_lunar_nights = True
radiation_protection = True

# %%
print("Challenges of Landing on Lunar South Pole:")
print(f"Surface Roughness: {surface_roughness}/10")
print(f"Permanently Shadowed Regions: {permanently_shadowed_regions}")
print(f"Extreme Cold Temperature: {extreme_cold_temperature}°C")
print(f"Extreme Hot Temperature: {extreme_hot_temperature}°C")
print(f"Limited Line of Sight: {limited_line_of_sight}")
print(f"Signal Delays: {signal_delays}")
print(f"Low Sun Angle: {low_sun_angle}")
print(f"Abrasive Dust: {abrasive_dust}/10")
print(f"Electrostatic Levitation: {electrostatic_levitation}")
print(f"Limited Landmarks: {limited_landmarks}")
print(f"Solar Radiation: {solar_radiation}/10")
print(f"Cosmic Radiation: {cosmic_radiation}/10")
print(f"Long Lunar Nights: {long_lunar_nights}")
print(f"Radiation Protection: {radiation_protection}")
# Out:
# Challenges of Landing on Lunar South Pole:
# Surface Roughness: 8/10
# Permanently Shadowed Regions: True
# Extreme Cold Temperature: -157°C
# Extreme Hot Temperature: 120°C
# Limited Line of Sight: True
# Signal Delays: True
# Low Sun Angle: True
# Abrasive Dust: 7/10
# Electrostatic Levitation: True
# Limited Landmarks: True
# Solar Radiation: 9/10
# Cosmic Radiation: 9/10
# Long Lunar Nights: True
# Radiation Protection: True

# %%
rover_mass = 26
rover_power = 50
rover_battery_capacity = 2000
lander_mass = 1749.86
propellant_mass = 1696.39
isp_lander_engine = 300
delta_v_required = 1500
moon_surface_temperature_night = -233
moon_surface_temperature_day = 127
maximum_operational_temperature = 50
rover_operating_hours_day = rover_battery_capacity / rover_power
rover_operating_hours_night = rover_battery_capacity / (rover_power / 2)
rover_can_operate = rover_operating_hours_day >= 14 * 24 and rover_operating_hours_night
lander_battery_capacity = 2000
lander_can_operate = lander_battery_capacity >= 14 * 24 * rover_power
abrasive_lunar_dust_rating = 7
mobility_on_dust = rover_can_operate and abrasive_lunar_dust_rating <= 5
solar_radiation_rating = 7
radiation_protection = solar_radiation_rating >= 5
temperature_constraints_met = (
 -moon_surface_temperature_night <= maximum_operational_temperature <= moon_surface_t
)
mission_success = (
 rover_can_operate
 and lander_can_operate
 and mobility_on_dust
 and radiation_protection
 and temperature_constraints_met
 and (propellant_mass >= propellant_required)
)

# %%
print(f"Rover can operate for {rover_operating_hours_day} hours during lunar day and {rover_operating_hours_night} hours during night")
print(f"Lander can power the rover for 14 Earth days: {lander_can_operate}.")
print(f"Rover can operate on abrasive lunar dust (rating {abrasive_lunar_dust_rating})")
print(f"Rover and lander provide adequate radiation protection (rating {solar_radiation_rating})")
print(f"Components stay within temperature limits: {temperature_constraints_met}.")
print(f"Is the mission successful? {mission_success}")
# Out:
# Rover can operate for 40.0 hours during lunar day and 80.0 hours during night
# Lander can power the rover for 14 Earth days: False.
# Rover can operate on abrasive lunar dust (rating 7)
# Rover and lander provide adequate radiation protection (rating 7)
# Components stay within temperature limits: False.
# Is the mission successful? False

# %%
import random
success_criteria = {
 "Terrain": "Flat",
 "Propellant Mass": 1696.39,
 "Power Margin": 0.2,
 "Communication": "Good",
 "Payloads": 3,
}
lander = {
 "Terrain": random.choice(["Flat", "Rough", "Cratered"]),
 "Propellant Mass": random.uniform(1600, 1800),
 "Power Margin": random.uniform(0.15, 0.25),
 "Communication": random.choice(["Good", "Poor"]),
 "Payloads": random.randint(1, 5),
}
rover = {
 "Terrain": random.choice(["Flat", "Rough", "Cratered"]),
 "Mass": random.uniform(20, 30),
 "Power": random.uniform(40, 60),
 "Payloads": random.randint(1, 3),
}
def predict_landing_success(lander, rover, success_criteria):
 success = True
 if lander["Terrain"] != success_criteria["Terrain"]:
  success = False
 propellant_margin = (success_criteria["Propellant Mass"] - lander["Propellant Mass"])
 if propellant_margin < -success_criteria["Power Margin"]:
  success = False
 if lander["Communication"] != success_criteria["Communication"]:
  success = False
 if lander["Payloads"] < success_criteria["Payloads"]:
  success = False
 return success

# %%
landing_success = predict_landing_success(lander, rover, success_criteria)
if landing_success:
 print("Lunar landing is predicted to be successful!")
else:
 print("Lunar landing is predicted to be unsuccessful.")
# Out:
# Lunar landing is predicted to be unsuccessful.

# %% [markdown]
# #CHANDRAYAAN-2

# %%
rover_mass = 27
lander_dry_mass = 1471
total_mass = rover_mass + lander_dry_mass
delta_v_required = 1500
isp_lander_engine = 300
propellant_mass_required = total_mass * math.exp(delta_v_required / isp_lander_engine)
propellant_mass_required = round(propellant_mass_required, 2)

# %%
rover_power_requirement = 50
lander_battery_capacity = 650
rover_operating_time_hours = lander_battery_capacity / rover_power_requirement

# %%
print("Mass Budget:")
print(f"Lander mass: {lander_dry_mass} kg")
print(f"Rover mass: {rover_mass} kg")
print(f"Propellant mass required: {propellant_mass_required} kg matches value in Lander")
print("\nPower Budget:")
print(f"Rover power requirement: {rover_power_requirement} W")
print(f"Lander battery capacity: {lander_battery_capacity} Wh")
print(f"Rover can operate for {rover_operating_time_hours:.2f} hours on stored power")
print("\nMobility Assessment:")
print("Low mass of the rover allows for mobility on uneven lunar surface")
print("Number of payloads for science measurements is 2")
# Out:
# Mass Budget:
# Lander mass: 1471 kg
# Rover mass: 27 kg
# Propellant mass required: 222322.91 kg matches value in Lander
#
# Power Budget:
# Rover power requirement: 50 W
# Lander battery capacity: 650 Wh
# Rover can operate for 13.00 hours on stored power
#
# Mobility Assessment:
# Low mass of the rover allows for mobility on uneven lunar surface
# Number of payloads for science measurements is 2

# %%
import matplotlib.pyplot as plt
labels = ['Lander Dry Mass', 'Rover Mass', 'Propellant Mass']
mass_values = [lander_dry_mass, rover_mass, propellant_mass_required]
plt.figure(figsize=(8, 6))
plt.bar(labels, mass_values, color=['blue', 'green', 'orange'])
plt.xlabel('Components')
plt.ylabel('Mass (kg)')
plt.title('Mass Budget')
plt.ylim(0, max(mass_values) * 1.2)
for i, v in enumerate(mass_values):
 plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
labels = ['Rover Power Requirement', 'Lander Battery Capacity']
power_values = [rover_power_requirement, lander_battery_capacity]
plt.figure(figsize=(8, 6))
plt.bar(labels, power_values, color=['blue', 'green'])
plt.xlabel('Components')
plt.ylabel('Power (Watt-hours)')
plt.title('Power Budget')
plt.ylim(0, max(power_values) * 1.2)
for i, v in enumerate(power_values):
 plt.text(i, v, str(v), ha='center', va='bottom')
plt.show()

# %%
import plotly.express as px
mass_labels = ['Lander Dry Mass', 'Rover Mass', 'Propellant Mass']
mass_values = [lander_dry_mass, rover_mass, propellant_mass_required]
mass_fig = px.bar(x=mass_labels, y=mass_values, color=mass_labels,
 labels={'x': 'Components', 'y': 'Mass (kg)'},
 title='Mass Budget')
mass_fig.update_traces(texttemplate='%{y:.2f} kg', textposition='outside')
mass_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1213f270-49a0-41da-8b44-df999061df8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1213f270-49a0-41da-8b44-df999061df8b")) {                    Plotly.newPlot(                        "1213f270-49a0-41da-8b44-df999061df8b",                        [{"alignmentgroup":"True","hovertemplate":"color=Lander Dry Mass\u003cbr\u003eComponents=%{x}\u003cbr\u003eMass (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lander Dry Mass","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Lander Dry Mass","offsetgroup":"Lander Dry Mass","orientation":"v","showlegend":true,"textposition":"outside","x":["Lander Dry Mass"],"xaxis":"x","y":[1471.0],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} kg"},{"alignmentgroup":"True","hovertemplate":"color=Rover Mass\u003cbr\u003eComponents=%{x}\u003cbr\u003eMass (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rover Mass","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Rover Mass","offsetgroup":"Rover Mass","orientation":"v","showlegend":true,"textposition":"outside","x":["Rover Mass"],"xaxis":"x","y":[27.0],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} kg"},{"alignmentgroup":"True","hovertemplate":"color=Propellant Mass\u003cbr\u003eComponents=%{x}\u003cbr\u003eMass (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Propellant Mass","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Propellant Mass","offsetgroup":"Propellant Mass","orientation":"v","showlegend":true,"textposition":"outside","x":["Propellant Mass"],"xaxis":"x","y":[222322.91],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} kg"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26" ...

# %%
power_labels = ['Rover Power Requirement', 'Lander Battery Capacity']
power_values = [rover_power_requirement, lander_battery_capacity]
power_fig = px.bar(x=power_labels, y=power_values, color=power_labels,
 labels={'x': 'Components', 'y': 'Power (Watt-hours)'},
 title='Power Budget')
power_fig.update_traces(texttemplate='%{y:.2f} Wh', textposition='outside')
power_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="187a889d-c778-4c9a-a110-b0968dd76c04" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("187a889d-c778-4c9a-a110-b0968dd76c04")) {                    Plotly.newPlot(                        "187a889d-c778-4c9a-a110-b0968dd76c04",                        [{"alignmentgroup":"True","hovertemplate":"color=Rover Power Requirement\u003cbr\u003eComponents=%{x}\u003cbr\u003ePower (Watt-hours)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rover Power Requirement","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rover Power Requirement","offsetgroup":"Rover Power Requirement","orientation":"v","showlegend":true,"textposition":"outside","x":["Rover Power Requirement"],"xaxis":"x","y":[50],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} Wh"},{"alignmentgroup":"True","hovertemplate":"color=Lander Battery Capacity\u003cbr\u003eComponents=%{x}\u003cbr\u003ePower (Watt-hours)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lander Battery Capacity","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Lander Battery Capacity","offsetgroup":"Lander Battery Capacity","orientation":"v","showlegend":true,"textposition":"outside","x":["Lander Battery Capacity"],"xaxis":"x","y":[650],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f} Wh"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %%
plt.figure(figsize=(20, 20))
plt.pie(mass_values, labels=mass_labels, autopct='%1.1f%%', startangle=140)
plt.title('Mass Budget')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(power_values, labels=power_labels, autopct='%1.1f%%', startangle=140)
plt.title('Power Budget')
plt.axis('equal')
plt.show()

# %%
mass_fig = px.pie(names=mass_labels, values=mass_values, title='Mass Budget')
mass_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ba2be6dc-6d1e-46ba-ada8-1ff342b425f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba2be6dc-6d1e-46ba-ada8-1ff342b425f8")) {                    Plotly.newPlot(                        "ba2be6dc-6d1e-46ba-ada8-1ff342b425f8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Lander Dry Mass","Rover Mass","Propellant Mass"],"legendgroup":"","name":"","showlegend":true,"values":[1471.0,27.0,222322.91],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth ...

# %%
power_fig = px.pie(names=power_labels, values=power_values, title='Power Budget')
power_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a6f58c42-1992-45b7-b76c-7b7f65aafa64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6f58c42-1992-45b7-b76c-7b7f65aafa64")) {                    Plotly.newPlot(                        "a6f58c42-1992-45b7-b76c-7b7f65aafa64",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Rover Power Requirement","Lander Battery Capacity"],"legendgroup":"","name":"","showlegend":true,"values":[50,650],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks": ...

# %%
surface_roughness = 8
permanently_shadowed_regions = True
extreme_cold_temperature = -157
extreme_hot_temperature = 120
limited_line_of_sight = True
signal_delays = True
low_sun_angle = True
abrasive_dust = 7
electrostatic_levitation = True
limited_landmarks = True
solar_radiation = 9
cosmic_radiation = 9
long_lunar_nights = True
radiation_protection = True

# %%
print("Challenges of Landing on Lunar South Pole:")
print(f"Surface Roughness: {surface_roughness}/10")
print(f"Permanently Shadowed Regions: {permanently_shadowed_regions}")
print(f"Extreme Cold Temperature: {extreme_cold_temperature}°C")
print(f"Extreme Hot Temperature: {extreme_hot_temperature}°C")
print(f"Limited Line of Sight: {limited_line_of_sight}")
print(f"Signal Delays: {signal_delays}")
print(f"Low Sun Angle: {low_sun_angle}")
print(f"Abrasive Dust: {abrasive_dust}/10")
print(f"Electrostatic Levitation: {electrostatic_levitation}")
print(f"Limited Landmarks: {limited_landmarks}")
print(f"Solar Radiation: {solar_radiation}/10")
print(f"Cosmic Radiation: {cosmic_radiation}/10")
print(f"Long Lunar Nights: {long_lunar_nights}")
print(f"Radiation Protection: {radiation_protection}")
# Out:
# Challenges of Landing on Lunar South Pole:
# Surface Roughness: 8/10
# Permanently Shadowed Regions: True
# Extreme Cold Temperature: -157°C
# Extreme Hot Temperature: 120°C
# Limited Line of Sight: True
# Signal Delays: True
# Low Sun Angle: True
# Abrasive Dust: 7/10
# Electrostatic Levitation: True
# Limited Landmarks: True
# Solar Radiation: 9/10
# Cosmic Radiation: 9/10
# Long Lunar Nights: True
# Radiation Protection: True

# %%
rover_mass = 27
rover_power = 50
rover_battery_capacity = 650
lander_mass = 1471
propellant_mass = 1697
isp_lander_engine = 300
delta_v_required = 1500
moon_surface_temperature_night = -233
moon_surface_temperature_day = 127
maximum_operational_temperature = 50
rover_operating_hours_day = rover_battery_capacity / rover_power
rover_operating_hours_night = rover_battery_capacity / (rover_power / 2)
rover_can_operate = rover_operating_hours_day >= 14 * 24 and rover_operating_hours_night
lander_battery_capacity = 650
lander_can_operate = lander_battery_capacity >= 14 * 24 * rover_power
abrasive_lunar_dust_rating = 7
mobility_on_dust = rover_can_operate and abrasive_lunar_dust_rating <= 5
solar_radiation_rating = 7
radiation_protection = solar_radiation_rating >= 5
temperature_constraints_met = (
 -moon_surface_temperature_night <= maximum_operational_temperature <= moon_surface_t
)
mission_success = (
 rover_can_operate
 and lander_can_operate
 and mobility_on_dust
 and radiation_protection
 and temperature_constraints_met
 and (propellant_mass >= propellant_required)
)

# %%
print(f"Rover can operate for {rover_operating_hours_day} hours during lunar day and {rover_operating_hours_night} hours during night")
print(f"Lander can power the rover for 14 Earth days: {lander_can_operate}.")
print(f"Rover can operate on abrasive lunar dust (rating {abrasive_lunar_dust_rating})")
print(f"Rover and lander provide adequate radiation protection (rating {solar_radiation_rating})")
print(f"Components stay within temperature limits: {temperature_constraints_met}.")
print(f"Is the mission successful? {mission_success}")
# Out:
# Rover can operate for 13.0 hours during lunar day and 26.0 hours during night
# Lander can power the rover for 14 Earth days: False.
# Rover can operate on abrasive lunar dust (rating 7)
# Rover and lander provide adequate radiation protection (rating 7)
# Components stay within temperature limits: False.
# Is the mission successful? False

# %%
import random
success_criteria = {
 "Terrain": "Flat",
 "Propellant Mass": 1697,
 "Power Margin": 0.2,
 "Communication": "Good",
 "Payloads": 3,
}
lander = {
 "Terrain": random.choice(["Flat", "Rough", "Cratered"]),
 "Propellant Mass": random.uniform(1600, 1800),
 "Power Margin": random.uniform(0.15, 0.25),
 "Communication": random.choice(["Good", "Poor"]),
 "Payloads": random.randint(1, 5),
}
rover = {
 "Terrain": random.choice(["Flat", "Rough", "Cratered"]),
 "Mass": random.uniform(20, 30),
 "Power": random.uniform(40, 60),
 "Payloads": random.randint(1, 3),
}
def predict_landing_success(lander, rover, success_criteria):
 success = True
 if lander["Terrain"] != success_criteria["Terrain"]:
  success = False
 propellant_margin = (success_criteria["Propellant Mass"] - lander["Propellant Mass"])
 if propellant_margin < -success_criteria["Power Margin"]:
  success = False
 if lander["Communication"] != success_criteria["Communication"]:
  success = False
 if lander["Payloads"] < success_criteria["Payloads"]:
  success = False
 return success

# %%
landing_success = predict_landing_success(lander, rover, success_criteria)
if landing_success:
 print("Lunar landing is predicted to be successful!")
else:
 print("Lunar landing is predicted to be unsuccessful.")
# Out:
# Lunar landing is predicted to be unsuccessful.
